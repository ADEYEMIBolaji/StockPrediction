# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import train_test_split
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from itertools import cycle
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
AAPL = pd.read_csv(r"C:\Users\bolaj\Desktop\Stock Price Prediction\Stock Market Price  Prediction\Methodology\AAPL_daily_data.csv")
TSLA = pd.read_csv('C:/Users/bolaj/Desktop/Stock Price Prediction/Stock Market Price  Prediction/Methodology/TSLA_daily_data.csv')
GOOG = pd.read_csv('C:/Users/bolaj/Desktop/Stock Price Prediction/Stock Market Price  Prediction/Methodology/GOOGL_daily_data.csv')
MSFT = pd.read_csv('C:/Users/bolaj/Desktop/Stock Price Prediction/Stock Market Price  Prediction/Methodology/MSFT_daily_data.csv')
AMZN = pd.read_csv('C:/Users/bolaj/Desktop/Stock Price Prediction/Stock Market Price  Prediction/Methodology/AMZN_daily_data.csv')

# %%
def Test_Stationarity(timeseries):
  result = adfuller(timeseries['Adj Close'], autolag = 'AIC')
  print("Results of Dickey Fuller Test")
  print(f'Test Statistics: {result[0]}')
  print(f'p-value: {result[1]}')
  print(f'Number of lags used: {result[2]}')
  print(f'Number of observations used: {result[3]}')
  for key, value in result[4].items():
    print(f'critical value ({key}): {value}')

# %% [markdown]
# ## APPLE

# %% [markdown]
# ### Preamble

# %%
AAPL.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2014-01-02  19.845715  19.893929  19.715000  19.754642  17.253262
# 1  2014-01-03  19.745001  19.775000  19.301071  19.320715  16.874273
# 2  2014-01-06  19.194643  19.528570  19.057142  19.426071  16.966291
# 3  2014-01-07  19.440001  19.498571  19.211430  19.287144  16.844955
# 4  2014-01-08  19.243214  19.484285  19.238930  19.409286  16.951630
#
#       Volume
# 0  234684800
# 1  392467600
# 2  412610800
# 3  317209200
# 4  258529600

# %%
AAPL.shape
# Out:
# (2684, 7)

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2684 entries, 0 to 2683
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2684 non-null   object
#  1   Open       2684 non-null   float64
#  2   High       2684 non-null   float64
#  3   Low        2684 non-null   float64
#  4   Close      2684 non-null   float64
#  5   Adj Close  2684 non-null   float64
#  6   Volume     2684 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 146.9+ KB

# %%
AAPL.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# Change Dtype of Date column
AAPL["Date"] = pd.to_datetime(AAPL["Date"])

# %%
max_date = AAPL["Date"].max()
max_date
# Out:
# Timestamp('2024-08-30 00:00:00')

# %%
min_date = AAPL["Date"].min()
min_date
# Out:
# Timestamp('2014-01-02 00:00:00')

# %%
AAPL.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2014-01-02  19.845715  19.893929  19.715000  19.754642  17.253262  234684800
# 1 2014-01-03  19.745001  19.775000  19.301071  19.320715  16.874273  392467600
# 2 2014-01-06  19.194643  19.528570  19.057142  19.426071  16.966291  412610800
# 3 2014-01-07  19.440001  19.498571  19.211430  19.287144  16.844955  317209200
# 4 2014-01-08  19.243214  19.484285  19.238930  19.409286  16.951630  258529600

# %%
Test_Stationarity(AAPL)
# Out:
# Results of Dickey Fuller Test
# Test Statistics: 0.7418151342831563
# p-value: 0.9906364642570723
# Number of lags used: 9
# Number of observations used: 2674
# critical value (1%): -3.4327978640972296
# critical value (5%): -2.8626214842914908
# critical value (10%): -2.5673457107278095

# %%
# Function to detect outliers using IQR (Interquartile Range)
def detect_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Return a boolean series where True indicates an outlier
    return (df[column] < lower_bound) | (df[column] > upper_bound)

# %%
# Detect outliers for each numeric column (Open, High, Low, Close, Adj Close, Volume)
for column in ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']:
    outliers = detect_outliers_iqr(AAPL, column)
    num_outliers = outliers.sum()
    print(f"Number of outliers in {column}: {num_outliers}")
# Out:
# Number of outliers in Open: 0
# Number of outliers in High: 0
# Number of outliers in Low: 0
# Number of outliers in Close: 0
# Number of outliers in Adj Close: 0
# Number of outliers in Volume: 127

# %%
# Visualize the Volume column separately
plt.figure(figsize=(5, 6))
sns.boxplot(data=AAPL['Volume'])
plt.title('AAPL: Boxplot for Volume Column')
plt.ylabel('Volume')

plt.savefig('AAPLvolume_boxplot.png', format='png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# Get the rows where Volume is an outlier
AAPLvolume_outliers = AAPL[detect_outliers_iqr(AAPL, 'Volume')]

# Display the outliers
AAPLvolume_outliers
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 1    2014-01-03   19.745001   19.775000   19.301071   19.320715   16.874273
# 2    2014-01-06   19.194643   19.528570   19.057142   19.426071   16.966291
# 3    2014-01-07   19.440001   19.498571   19.211430   19.287144   16.844955
# 6    2014-01-10   19.279642   19.314285   18.968214   19.033571   16.623491
# 7    2014-01-13   18.925358   19.375000   18.924286   19.133215   16.710512
# ...         ...         ...         ...         ...         ...         ...
# 1656 2020-07-31  102.885002  106.415001  100.824997  106.260002  103.655144
# 1657 2020-08-03  108.199997  111.637497  107.892502  108.937500  106.267021
# 1671 2020-08-21  119.262497  124.867500  119.250000  124.370003  121.539948
# 1672 2020-08-24  128.697495  128.785004  123.937500  125.857498  122.993591
# 1681 2020-09-04  120.070000  123.699997  110.889999  120.959999  118.207542
#
#          Volume
# 1     392467600
# 2     412610800
# 3     317209200
# 6     304976000
# 7     378492800
# ...         ...
# 1656  374336800
# 1657  308151200
# 1671  338054800
# 1672  345937600
# 1681  332607200
#
# [127 rows x 7 columns]

# %%
# Create a scatter plot for Volume highlighting outliers
plt.figure(figsize=(12, 6))
sns.scatterplot(data=AAPL, x='Date', y='Volume', hue=detect_outliers_iqr(AAPL, 'Volume'), palette={False: 'blue', True: 'red'})
plt.title('AAPL: Volume with Outliers Highlighted in Red')
plt.xticks(rotation=45)

# Save the figure as a PNG file
plt.savefig('AAPLvolume_scatterplot_outliers.png', format='png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# Summary statistics for outliers and non-outliers
print("Non-outlier Volume statistics:")
print(AAPL[~detect_outliers_iqr(AAPL, 'Volume')]['Volume'].describe())

print("\nOutlier Volume statistics:")
print(AAPL[detect_outliers_iqr(AAPL, 'Volume')]['Volume'].describe())
# Out:
# Non-outlier Volume statistics:
# count    2.557000e+03
# mean     1.193232e+08
# std      5.818103e+07
# min      2.404830e+07
# 25%      7.516930e+07
# 50%      1.050104e+08
# 75%      1.514468e+08
# max      2.927092e+08
# Name: Volume, dtype: float64
#
# Outlier Volume statistics:
# count    1.270000e+02
# mean     3.866642e+08
# std      1.083632e+08
# min      2.934616e+08
# 25%      3.200766e+08
# 50%      3.651500e+08
# 75%      4.024662e+08
# max      1.065523e+09
# Name: Volume, dtype: float64

# %%
AAPL['log Adj Close'] = np.log(AAPL['Adj Close'])
AAPL_log_moving_avg = AAPL['log Adj Close'].rolling(12).mean()
AAPL_log_std = AAPL['log Adj Close'].rolling(12).std()

plt.figure(figsize = (10, 5))
plt.plot(AAPL['Date'], AAPL_log_moving_avg, label = "Rolling Mean")
plt.plot(AAPL['Date'], AAPL_log_std, label = "Rolling Std")
plt.xlabel('Time')
plt.ylabel('log Adj Close')
plt.legend(loc = 'best')
plt.title("Rolling Mean and Standard Deviation")
# Out:
# Text(0.5, 1.0, 'Rolling Mean and Standard Deviation')

# %% [markdown]
# ### Split the data into training and test set
# Training Period: 2014-01-01 - 2023-09-30
#
# Testing Period:  2023-10-01 - 2024-04-01

# %%
AAPL.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'log Adj Close'],
#       dtype='object')

# %%
Base_AAPL = AAPL.set_index('Date')

# %%
Base_AAPL.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2014-01-02  19.845715  19.893929  19.715000  19.754642  17.253262  234684800
# 2014-01-03  19.745001  19.775000  19.301071  19.320715  16.874273  392467600
# 2014-01-06  19.194643  19.528570  19.057142  19.426071  16.966291  412610800
# 2014-01-07  19.440001  19.498571  19.211430  19.287144  16.844955  317209200
# 2014-01-08  19.243214  19.484285  19.238930  19.409286  16.951630  258529600
#
#             log Adj Close
# Date
# 2014-01-02       2.848001
# 2014-01-03       2.825790
# 2014-01-06       2.831229
# 2014-01-07       2.824051
# 2014-01-08       2.830364

# %%
# Calculate the correlation matrix
basecorr_matrix = Base_AAPL.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(basecorr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Add title
plt.title('Baseline Correlation Matrix of Features and Target (Close Price)', fontsize=16)
plt.savefig('Baseline Correlation Matrix of Features and Target (Close Price).png', format='png', dpi=300, bbox_inches='tight')

# Show plot
plt.show()

# %%
basecorr_matrix
# Out:
#                    Open      High       Low     Close  Adj Close    Volume  \
# Open           1.000000  0.999865  0.999863  0.999703   0.999666 -0.525633
# High           0.999865  1.000000  0.999818  0.999863   0.999817 -0.523110
# Low            0.999863  0.999818  1.000000  0.999860   0.999837 -0.528657
# Close          0.999703  0.999863  0.999860  1.000000   0.999962 -0.526093
# Adj Close      0.999666  0.999817  0.999837  0.999962   1.000000 -0.527094
# Volume        -0.525633 -0.523110 -0.528657 -0.526093  -0.527094  1.000000
# log Adj Close  0.969115  0.969582  0.968864  0.969337   0.968909 -0.570005
#
#                log Adj Close
# Open                0.969115
# High                0.969582
# Low                 0.968864
# Close               0.969337
# Adj Close           0.968909
# Volume             -0.570005
# log Adj Close       1.000000

# %%
# Create a DataFrame to store VIF values
vif_data = pd.DataFrame()
vif_data["Feature"] = Base_AAPL.columns

# Calculate VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(Base_AAPL.values, i) for i in range(len(Base_AAPL.columns))]

# Display the VIF values
vif_data
# Out:
#          Feature           VIF
# 0           Open  26264.367866
# 1           High  30388.937825
# 2            Low  29309.769669
# 3          Close  64979.881981
# 4      Adj Close  39985.207286
# 5         Volume      4.937573
# 6  log Adj Close     59.572918

# %%
# Define new feature set including the original and engineered features
X_base = Base_AAPL[[ 'Open', 'High', 'Low','Volume','log Adj Close']]
y_base = Base_AAPL['Close']

# %%
# Train-test split (80% train, 20% test)
X_trainbase, X_testbase, y_trainbase, y_testbase = train_test_split(X_base, y_base, test_size=0.2, shuffle=False)

# Initialize MinMaxScaler
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

# Scale the features and target
X_train_scaledbase = scaler_X.fit_transform(X_trainbase)
X_test_scaledbase = scaler_y.fit_transform(X_testbase)

# # Standardize the features
# scaler = StandardScaler()
# X_train_scaledbase = scaler.fit_transform(X_trainbase)
# X_test_scaledbase = scaler.transform(X_testbase)

# %% [markdown]
# ### Model Trainig & Prediction

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Function to calculate RMSE, MAE, and R²
def evaluate_model(true_values, predicted_values, model_name):
    rmse = np.sqrt(mean_squared_error(true_values, predicted_values))
    mae = mean_absolute_error(true_values, predicted_values)
    r2 = r2_score(true_values, predicted_values)
    
    print(f'{model_name} Evaluation:')
    print(f'  RMSE: {rmse:.4f}')
    print(f'  MAE: {mae:.4f}')
    print(f'  R²: {r2:.4f}\n')
    
    return rmse, mae, r2

# %% [markdown]
# #### Arima Baseline

# %% [markdown]
# ##### AutoArima

# %%
# Train the AutoARIMA model
AAPL_Auto_ARIMA_Model = auto_arima(y_trainbase, seasonal=False, stepwise=True)

# %%
# AAPL_Auto_ARIMA_Model = auto_arima(AAPL_Train_Data['log Adj Close'], seasonal = False,
#                                    error_action = 'ignore', suppress_warnings = True)
print(AAPL_Auto_ARIMA_Model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2147
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -3958.618
# Date:                Wed, 25 Sep 2024   AIC                           7923.236
# Time:                        18:48:19   BIC                           7940.250
# Sample:                             0   HQIC                          7929.461
#                                - 2147
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0586      0.031      1.881      0.060      -0.002       0.120
# ma.L1         -0.0601      0.011     -5.401      0.000      -0.082      -0.038
# sigma2         2.3430      0.031     76.150      0.000       2.283       2.403
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              7057.69
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):              38.17   Skew:                            -0.17
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
auto_arima_fitted = AAPL_Auto_ARIMA_Model.fit(y_trainbase)

# %%
# Predictions
AAPL_Auto_ARIMA_Model_pred = auto_arima_fitted.predict(n_periods=len(y_testbase))

# %%
# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(y_testbase.index, y_testbase, label='True Close Price')
plt.plot(y_testbase.index, AAPL_Auto_ARIMA_Model_pred, label='Auto ARIMA Predicted Close Price', color='red')
plt.title('Baseline Auto ARIMA Model - Close Price Prediction')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.savefig('AAPLAuto ARIMA Model - Baseline Price Prediction.png', format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Evaluate Auto ARIMA model predictions
auto_arima_rmse, auto_arima_mae, auto_arima_r2 = evaluate_model(y_testbase, AAPL_Auto_ARIMA_Model_pred, "Auto ARIMA")
# Out:
# Auto ARIMA Evaluation:
#   RMSE: 21.5505
#   MAE: 17.0526
#   R²: 0.1584

# %% [markdown]
# ##### Arima

# %%
# ARIMA Model (let's assume p=5, d=1, q=0 as an example)
AAPL_arima_model = ARIMA(y_trainbase, order=(1, 1, 0))
AAPL_arima_fitted = AAPL_arima_model.fit()

# %%
# Predicting on test set
AAPL_arima_pred = AAPL_arima_fitted.predict(start=len(y_trainbase), end=len(y_trainbase)+len(y_testbase)-1, typ='levels')

# %%
# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(y_testbase.index, y_testbase, label='True Close Price')
plt.plot(y_testbase.index, AAPL_arima_pred, label='ARIMA Predicted Close Price', color='red')
plt.title('Baseline ARIMA Model - Close Price Prediction')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Evaluate ARIMA model predictions
arima_rmse, arima_mae, arima_r2 = evaluate_model(y_testbase, AAPL_arima_pred, "ARIMA")
# Out:
# ARIMA Evaluation:
#   RMSE: 37.2894
#   MAE: 30.6785
#   R²: -1.5196

# %%
plt.figure(figsize=(10, 6))

# Actual Closing Price
plt.plot(y_testbase.index, y_testbase, color='blue', label='Actual Closing Price', linewidth=2)

# ARIMA Predicted Closing Price
plt.plot(y_testbase.index, AAPL_arima_pred, color='red', linestyle='--', label='ARIMA Predicted Price', linewidth=2)

# Auto ARIMA Predicted Closing Price
plt.plot(y_testbase.index, AAPL_Auto_ARIMA_Model_pred, color='green', linestyle='--', label='Auto ARIMA Predicted Price', linewidth=2)

plt.title('AAPL Baseline Actual vs Predicted Closing Price: ARIMA vs Auto ARIMA Feature Engineering', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Stock Price (USD)', fontsize=12)
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.savefig('AAPL Baseline ARIMA vs Auto ARIMA Model Closing Prediction.png', format='png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
# Simple Moving Average (SMA)
AAPL['SMA_20'] = AAPL['Close'].rolling(window=20).mean()

# %%
# Rate of Change (RoC)
AAPL['RoC_10'] = AAPL['Close'].pct_change(periods=10) * 100  # RoC for 10 days

# %%
AAPL.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 2679 2024-08-26  226.759995  227.279999  223.889999  227.179993  227.179993
# 2680 2024-08-27  226.000000  228.850006  224.889999  228.029999  228.029999
# 2681 2024-08-28  227.919998  229.860001  225.679993  226.490005  226.490005
# 2682 2024-08-29  230.100006  232.919998  228.880005  229.789993  229.789993
# 2683 2024-08-30  230.190002  230.399994  227.479996  229.000000  229.000000
#
#         Volume  log Adj Close    SMA_20    RoC_10
# 2679  30602200       5.425743  220.1805  4.436167
# 2680  35934600       5.429477  220.6420  3.055089
# 2681  38052200       5.422701  220.8625  2.151364
# 2682  51906300       5.437166  221.4340  2.256137
# 2683  52990800       5.433722  221.8910  1.305020

# %%
def compute_rsi(series, period=14):
    delta = series.diff(1)
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)
    avg_gain = gain.rolling(window=period, min_periods=1).mean()
    avg_loss = loss.rolling(window=period, min_periods=1).mean()
    rs = avg_gain / avg_loss
    return 100 - (100 / (1 + rs))

AAPL['RSI_14'] = compute_rsi(AAPL['Close'], period=14)

# %%
AAPL.sample(frac=0.0045)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 2218 2022-10-24  147.190002  150.229996  146.000000  149.449997  147.812256
# 2003 2021-12-15  175.110001  179.500000  172.309998  179.300003  176.604370
# 2390 2023-07-03  193.779999  193.880005  191.759995  192.460007  191.221954
# 735  2016-12-01   27.592501   27.735001   27.257500   27.372499   25.377874
# 2352 2023-05-08  172.479996  173.850006  172.110001  173.500000  172.145813
# 558  2016-03-22   26.312500   26.822500   26.302500   26.680000   24.328766
# 582  2016-04-26   25.977501   26.325001   25.977501   26.087500   23.788477
# 2413 2023-08-04  185.520004  187.380005  181.919998  181.990005  180.819305
# 933  2017-09-15   39.617500   40.242500   39.500000   39.970001   37.518440
# 432  2015-09-21   28.417500   28.842501   28.415001   28.802500   26.011133
# 2322 2023-03-24  158.860001  160.339996  157.850006  160.250000  158.999237
# 2194 2022-09-20  153.399994  158.080002  153.080002  156.899994  155.180603
#
#          Volume  log Adj Close      SMA_20    RoC_10     RSI_14
# 2218   75981900       4.995943  143.599499  6.430707  55.529864
# 2003  131063300       5.173912  166.198001  8.818352  68.943684
# 2390   31458200       5.253435  185.068501  4.077444  71.260503
# 735   148347600       3.233878   27.495625 -0.454587  56.558627
# 2352   55962800       5.148342  166.603000  4.941631  65.079344
# 558   129777600       3.191659   25.464000  5.631993  79.008771
# 582   224064800       3.169201   27.171000 -5.514310  26.676046
# 2413  115799700       5.197498  192.165001 -5.183910  27.203654
# 933   196458400       3.624833   40.167875 -2.512192  50.057816
# 432   200888000       3.258525   27.938000  5.436078  54.237282
# 2322   59196500       5.068899  152.778000  7.912458  63.253513
# 2194  107689800       5.044590  158.451999  1.533680  47.464030

# %%
# Price Range (High - Low)
AAPL['Price_Range'] = AAPL['High'] - AAPL['Low']

# %%
AAPL.sample(frac=0.00045)
# Out:
#            Date       Open     High   Low      Close  Adj Close     Volume  \
# 1564 2020-03-20  61.794998  62.9575  57.0  57.310001  55.754185  401693200
#
#       log Adj Close     SMA_20     RoC_10     RSI_14  Price_Range
# 1564       4.020952  68.343875 -20.686432  33.860711       5.9575

# %%
# Stock Returns
AAPL['Returns'] = AAPL['Close'].pct_change() * 100

# %%
# 1. Bollinger Bands
def bollinger_bands(data, window=20, num_sd=2):
    sma = data['Close'].rolling(window=window).mean()
    rolling_std = data['Close'].rolling(window=window).std()
    data['Bollinger_Upper'] = sma + (rolling_std * num_sd)
    data['Bollinger_Lower'] = sma - (rolling_std * num_sd)
    return data

AAPL = bollinger_bands(AAPL)

# %%
# 2. Exponential Moving Averages (EMA)
AAPL['EMA_12'] = AAPL['Close'].ewm(span=12, adjust=False).mean()  # 12-day EMA
AAPL['EMA_26'] = AAPL['Close'].ewm(span=26, adjust=False).mean()  # 26-day EMA

# %%
# 3. MACD
AAPL['MACD'] = AAPL['EMA_12'] - AAPL['EMA_26']
AAPL['MACD_Signal'] = AAPL['MACD'].ewm(span=9, adjust=False).mean()  # Signal line (9-day EMA of MACD)

# %%
# Drop rows with NaN values after feature engineering
AAPL.dropna(inplace=True)

# %%
AAPL.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 19 2014-01-30  17.947857  18.089287  17.739286  17.849285  15.589161
# 20 2014-01-31  17.684999  17.911785  17.626785  17.878571  15.614738
# 21 2014-02-03  17.950357  18.133215  17.832144  17.911785  15.643756
# 22 2014-02-04  18.066071  18.195000  17.955713  18.171070  15.870198
# 23 2014-02-05  18.091429  18.402857  18.080357  18.306786  15.988740
#
#        Volume  log Adj Close     SMA_20     RoC_10     RSI_14  Price_Range  \
# 19  678501600       2.746576  19.260286 -10.330847  35.357867     0.350000
# 20  464797200       2.748215  19.166482  -9.679754  36.821497     0.285000
# 21  401464000       2.750072  19.096036  -7.239169  35.849028     0.301071
# 22  376681200       2.764443  19.033286  -7.336053  33.991781     0.239286
# 23  328344800       2.771885  18.984268  -7.056995  29.699815     0.322500
#
#      Returns  Bollinger_Upper  Bollinger_Lower     EMA_12     EMA_26  \
# 19 -0.193711        20.499702        18.020870  18.934954  19.252245
# 20  0.164071        20.526474        17.806491  18.772433  19.150491
# 21  0.185779        20.564061        17.628011  18.640026  19.058735
# 22  1.447566        20.548444        17.518127  18.567879  18.992982
# 23  0.746877        20.528009        17.440526  18.527711  18.942153
#
#         MACD  MACD_Signal
# 19 -0.317291    -0.135755
# 20 -0.378057    -0.184216
# 21 -0.418709    -0.231114
# 22 -0.425103    -0.269912
# 23 -0.414442    -0.298818

# %%
AAPL.set_index('Date', inplace=True)

# %%
AAPL.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'log Adj Close',
#        'SMA_20', 'RoC_10', 'RSI_14', 'Price_Range', 'Returns',
#        'Bollinger_Upper', 'Bollinger_Lower', 'EMA_12', 'EMA_26', 'MACD',
#        'MACD_Signal'],
#       dtype='object')

# %%
# Calculate the correlation matrix
corr_matrix = AAPL[[ 'Close', 'Volume', 'log Adj Close',
       'SMA_20', 'RoC_10', 'RSI_14', 'Price_Range', 'Returns',
       'Bollinger_Upper', 'Bollinger_Lower', 'EMA_12', 'EMA_26', 'MACD',
       'MACD_Signal']].corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Add title
plt.title('Correlation Matrix of Features and Target (Close Price) after feature Engineering', fontsize=16)
plt.savefig('Correlation Matrix of Features and Target (Close Price)after feature Engineering.png', format='png', dpi=300, bbox_inches='tight')
# Show plot
plt.show()

# %% [markdown]
# ### Arima Model Retraining

# %%
# Define new feature set including the original and engineered features
X = AAPL[['Volume','log Adj Close',
    'RoC_10', 'RSI_14', 'Price_Range', 'Returns', 'MACD',
       'MACD_Signal']]
y = AAPL['Close']

# %%
# Initialize MinMaxScaler
scaler = MinMaxScaler()

X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X.head()
# Out:
#      Volume  log Adj Close    RoC_10    RSI_14  Price_Range   Returns  \
# 0  0.889368       0.000000  0.238791  0.347191     0.013517  0.509991
# 1  0.598955       0.000605  0.253805  0.362965     0.009779  0.524391
# 2  0.512888       0.001290  0.310083  0.352484     0.010703  0.525265
# 3  0.479210       0.006590  0.307849  0.332468     0.007149  0.576050
# 4  0.413523       0.009335  0.314283  0.286212     0.011936  0.547848
#
#        MACD  MACD_Signal
# 0  0.406872     0.402088
# 1  0.402982     0.398657
# 2  0.400380     0.395337
# 3  0.399971     0.392591
# 4  0.400653     0.390544

# %%
# Train-test split (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

# TimeSeriesSplit for cross-validation (5 folds)
tscv = TimeSeriesSplit(n_splits=10)

# %%
import itertools

# Define the p, d, q ranges to search over
p = range(0, 5)
d = range(0, 2)
q = range(0, 5)
pdq = list(itertools.product(p, d, q))

# Grid search over p, d, q combinations
best_aic = np.inf
best_order = None
best_model = None

for order in pdq:
    try:
        model = ARIMA(y_train, order=order)
        results = model.fit()
        if results.aic < best_aic:
            best_aic = results.aic
            best_order = order
            best_model = results
    except:
        continue

print(f"Best ARIMA model: Order {best_order} with AIC {best_aic}")
# Out:
# Best ARIMA model: Order (4, 1, 4) with AIC 7855.666615362545

# %%
# Perform auto_arima with cross-validation
auto_arima_model_fe = auto_arima(y_train, 
                              exogenous=X_train,  # Using the new features
                              seasonal=False, 
                              trace=True,
                              error_action='ignore', 
                              suppress_warnings=True,
                              stepwise=True,
                              cv=tscv,
                              start_p=0, 
                              start_q=0, 
                              max_p=5, 
                              max_q=5, 
                              d=1)

# Print the best order found
print(f"Best Auto ARIMA model: {auto_arima_model_fe.order}")
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7901.879, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7895.966, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=7895.747, Time=0.20 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=7903.367, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=7897.198, Time=0.27 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=7897.403, Time=0.32 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=7899.193, Time=0.90 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=7897.711, Time=0.07 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 2.086 seconds
# Best Auto ARIMA model: (0, 1, 1)

# %% [markdown]
# ##### Prediciton and Evaluation

# %%
# Fit ARIMA with best hyperparameters
arima_fitted_fe = ARIMA(y_train, order=best_order).fit()

# Predict on the test set
arima_pred_fe = arima_fitted_fe.predict(start=len(y_train), end=len(y_train)+len(y_test)-1, typ='levels')

# Evaluate the ARIMA model
arima_rmse, arima_mae, arima_r2 = evaluate_model(y_test, arima_pred_fe, "ARIMA with Feature Engineering")
# Out:
# ARIMA with Feature Engineering Evaluation:
#   RMSE: 33.0046
#   MAE: 26.6891
#   R²: -0.9764

# %%
# Predict with the optimized Auto ARIMA model
auto_arima_pred_fe = auto_arima_model_fe.predict(n_periods=len(y_test), exogenous=X_test)

# Evaluate the Auto ARIMA model
auto_arima_rmse, auto_arima_mae, auto_arima_r2 = evaluate_model(y_test, auto_arima_pred_fe, "Auto ARIMA with Feature Engineering")
# Out:
# Auto ARIMA with Feature Engineering Evaluation:
#   RMSE: 18.2544
#   MAE: 14.5093
#   R²: 0.3954

# %%
def plot_predictions(actual, predicted, model_name):
    plt.figure(figsize=(10, 6))
    
    plt.plot(actual.index, actual, color='blue', label='Actual Closing Price', linewidth=2)
    plt.plot(actual.index, predicted, color='red', linestyle='--', label=f'{model_name} Predicted Price', linewidth=2)

    plt.title(f'{model_name} Model: Actual vs Predicted Closing Price', fontsize=14)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Stock Price (USD)', fontsize=12)
    plt.legend(loc='upper left')
    plt.xticks(rotation=45)
    
    plt.show()

# Plot ARIMA predictions
plot_predictions(y_test, arima_pred_fe, "ARIMA with Feature Engineering")

# %%
# Plot Auto ARIMA predictions
plot_predictions(y_test, auto_arima_pred_fe, "Auto ARIMA with Feature Engineering")

# %%
plt.figure(figsize=(10, 6))

# Actual Closing Price
plt.plot(y_test.index, y_test, color='blue', label='Actual Closing Price', linewidth=2)

# ARIMA Predicted Closing Price
plt.plot(y_test.index, arima_pred_fe, color='red', linestyle='--', label='ARIMA Predicted Price', linewidth=2)

# Auto ARIMA Predicted Closing Price
plt.plot(y_test.index, auto_arima_pred_fe, color='green', linestyle='--', label='Auto ARIMA Predicted Price', linewidth=2)

plt.title('AAPL Actual vs Predicted Closing Price: Final ARIMA vs Auto ARIMA Feature Engineering', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Stock Price (USD)', fontsize=12)
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.savefig('AAPL Final ARIMA vs Auto ARIMA Model Closing Prediction.png', format='png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
# Baseline model
baseline_model = RandomForestRegressor(random_state=42)
baseline_model.fit(X_train_scaledbase, y_trainbase)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict and evaluate
R_baseline_predictions = baseline_model.predict(X_test_scaledbase)

# %%
R_baseline_rmse, R_baseline_mae, R_baseline_r2 = evaluate_model(y_testbase, R_baseline_predictions, "Random Forest")
# Out:
# Random Forest Evaluation:
#   RMSE: 102.5217
#   MAE: 101.9606
#   R²: -18.0459

# %%
# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(y_testbase.index, y_testbase, label='True Close Price')
plt.plot(y_testbase.index, R_baseline_predictions, label='Random Forest Predicted Close Price', color='green')
plt.title('Random Forest Baseline Model - Close Price Prediction')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.savefig('AAPL Random Forest Baseline Model - Close Price Prediction.png', format='png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### Random Forest Final Prediction

# %%
from sklearn.model_selection import GridSearchCV

# Define the model
rf_model = RandomForestRegressor(random_state=42)

# %%
# Define the grid of hyperparameters to search
param_grid = {
    'n_estimators': [100,150,200],
    'max_features': ['auto', 'sqrt'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Set up GridSearchCV
grid_search = GridSearchCV(estimator=rf_model,
                           param_grid=param_grid,
                           cv=5,  # 5-fold cross-validation
                           verbose=0,
                           scoring='neg_mean_squared_error')

# %%
# Fit GridSearchCV
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 150, 200]},
#              scoring='neg_mean_squared_error')

# %%
# Best parameters and model
best_rf_model = grid_search.best_estimator_
print("Best Random Forest Parameters:", grid_search.best_params_)
# Out:
# Best Random Forest Parameters: {'max_depth': 30, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
# Predict and evaluate final model
final_predictions = best_rf_model.predict(X_test)

# %%
# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(y_test.index, y_test, label='True Close Price')
plt.plot(y_test.index, final_predictions, label='Random Forest Predicted Close Price', color='green')
plt.title('Final Random Forest Model - Close Price Prediction')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.savefig('AAPL Random Forest Final Model - Close Price Prediction.png', format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Evaluate Random Forest model predictions
rf_rmse, rf_mae, rf_r2 = evaluate_model(y_test, final_predictions, "Random Forest")
# Out:
# Random Forest Evaluation:
#   RMSE: 24.1284
#   MAE: 17.5588
#   R²: -0.0563

# %%
pred_dfr = pd.DataFrame({'Actual': y_test, 'Predicted': final_predictions})
pred_dfr.head()
# Out:
#                 Actual   Predicted
# Date
# 2022-07-20  153.039993  152.668901
# 2022-07-21  155.350006  155.079077
# 2022-07-22  154.089996  154.504301
# 2022-07-25  152.949997  150.863901
# 2022-07-26  151.600006  151.503903

# %%
import matplotlib.pyplot as plt

feature_importances = best_rf_model.feature_importances_
sorted_idx = np.argsort(feature_importances)

plt.figure(figsize=(10, 6))
plt.barh(range(len(sorted_idx)), feature_importances[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), X.columns[sorted_idx])
plt.xlabel('Feature Importance')
plt.title('Feature Importance for Random Forest Model')

# Save the figure as a PNG file
plt.savefig('AAPL Feature Importance for Random Forest Model.png', format='png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVR

# %%
# Baseline model
baseline_svm = SVR(kernel='linear')  # Linear kernel as a starting point
baseline_svm.fit(X_train_scaledbase, y_trainbase)
# Out:
# SVR(kernel='linear')

# %%
# Predict and evaluate
baseline_predictionsSVM = baseline_svm.predict(X_test_scaledbase)

# %%
# Evaluate SVM model predictions
base_svm_rmse, base_svm_mae, base_svm_r2 = evaluate_model(y_testbase, baseline_predictionsSVM, "SVM")
# Out:
# SVM Evaluation:
#   RMSE: 85.6145
#   MAE: 84.8281
#   R²: -12.2820

# %%
# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(y_testbase.index, y_testbase, label='True Close Price')
plt.plot(y_testbase.index, baseline_predictionsSVM, label='SVM Predicted Close Price', color='orange')
plt.title('Baseline SVM Model - Close Price Prediction')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.savefig('SVM Baseline Model - Close Price Prediction.png', format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Define the model
svm_model = SVR()

# %%
# Define the grid of hyperparameters to search
param_grid = {
    'kernel': ['linear', 'poly', 'rbf'],
    'C': [0.1, 1, 10, 100],
    'epsilon': [0.1, 0.5, 1.0],
}

# %%
# Set up GridSearchCV
grid_search_svm = GridSearchCV(estimator=svm_model,
                                param_grid=param_grid,
                                cv=5,  # 5-fold cross-validation
                                n_jobs=-1,  # Use all available cores
                                verbose=1,
                                scoring='neg_mean_squared_error')

# %%
# Fit GridSearchCV
grid_search_svm.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'epsilon': [0.1, 0.5, 1.0],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
# Best parameters and model
best_svm_model = grid_search_svm.best_estimator_
print("Best SVM Parameters:", grid_search_svm.best_params_)
# Out:
# Best SVM Parameters: {'C': 10, 'epsilon': 1.0, 'kernel': 'poly'}

# %%
# Predict and evaluate final model
final_predictions_svm = best_svm_model.predict(X_test)

# %%
# Evaluate SVM model predictions
svm_rmse, svm_mae, svm_r2 = evaluate_model(y_test, final_predictions_svm, "SVM")
# Out:
# SVM Evaluation:
#   RMSE: 1.5595
#   MAE: 1.1186
#   R²: 0.9956

# %%
# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(y_test.index, y_test, label='True Close Price')
plt.plot(y_test.index, final_predictions_svm, label='SVM Predicted Close Price', color='orange')
plt.title('AAPL SVM Baseline Model - Close Price Prediction')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.savefig('AAPL SVM Final Model - Close Price Prediction.png', format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# prediction
# y_pred_1 = model_1.predict(X_test)
pred_df = pd.DataFrame({'Actual': y_test, 'Predicted': final_predictions_svm})
pred_df.head()
# Out:
#                 Actual   Predicted
# Date
# 2022-07-20  153.039993  152.966273
# 2022-07-21  155.350006  154.607316
# 2022-07-22  154.089996  153.014194
# 2022-07-25  152.949997  151.945474
# 2022-07-26  151.600006  151.008385

# %% [markdown]
# ### LSTM

# %%
# !pip install scikeras[tensorflow]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
import keras_tuner as kt
from tensorflow.keras.layers import LSTM, Dense, Dropout
from scikeras.wrappers import KerasRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score

# %%
AAPL.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'log Adj Close',
#        'SMA_20', 'RoC_10', 'RSI_14', 'Price_Range', 'Returns',
#        'Bollinger_Upper', 'Bollinger_Lower', 'EMA_12', 'EMA_26', 'MACD',
#        'MACD_Signal'],
#       dtype='object')

# %%
closedf = AAPL[['Close']]

# %%
# Apply MinMaxScaler
scaler= MinMaxScaler(feature_range=(0, 1))

# %%
closedf = scaler.fit_transform(np.array(closedf).reshape(-1,1))
print(closedf.shape)
# Out:
# (2665, 1)

# %%
# we keep the training set as 80% and 20% testing set
training_size=int(len(closedf)*0.80)
test_size=len(closedf)-training_size
train_data,test_data=closedf[0:training_size,:],closedf[training_size:len(closedf),:1]
print("train_data: ", train_data.shape)
print("test_data: ", test_data.shape)
# Out:
# train_data:  (2132, 1)
# test_data:  (533, 1)

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]    
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 30
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train:  (2101, 30)
# y_train:  (2101,)
# X_test:  (502, 30)
# y_test (502,)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print("X_train: ", X_train.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train:  (2101, 30, 1)
# X_test:  (502, 30, 1)

# %%
# model=Sequential()

# model.add(LSTM(10,input_shape=(None,1),activation="relu"))

# model.add(Dense(1))

# model.compile(loss="mean_squared_error",optimizer="adam")

# %%
def Reg():
    model = Sequential()
    
    model.add(LSTM(70, return_sequences=True, input_shape=(30,1)))
    model.add(LSTM(70, return_sequences=True))
    model.add(LSTM(70))
    model.add(Dense(1))
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    return model

# %%
# history = model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=200,batch_size=32,verbose=1)

# %%
model = Reg()
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - loss: 0.0059 - val_loss: 0.0014
# Epoch 2/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 2.3982e-04 - val_loss: 0.0028
# Epoch 3/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 2.5055e-04 - val_loss: 9.7880e-04
# Epoch 4/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 2.5885e-04 - val_loss: 0.0016
# Epoch 5/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 2.1494e-04 - val_loss: 7.9961e-04
# Epoch 6/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1.4728e-04 - val_loss: 7.5566e-04
# Epoch 7/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.3168e-04 - val_loss: 7.0875e-04
# Epoch 8/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 1.5971e-04 - val_loss: 0.0010
# Epoch 9/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 1.3898e-04 - val_loss: 9.8041e-04
# Epoch 10/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 1.5204e-04 - val_loss: 7.1979e-04
# Epoch 11/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 1.3592e-04 - val_loss: 5.9714e-04
# Epoch 12/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 1.0720e-04 - val_loss: 6.6356e-04
# Epoch 13/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 1.2498e-04 - val_loss: 8.2005e-04
# Epoch 14/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 9.3995e-05 - val_loss: 0.0014
# Epoch 15/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 1.1187e-04 - val_loss: 9.4974e-04
# Epoch 16/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 1.0294e-04 - val_loss: 5.3853e-04
# Epoch 17/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 9.1961e-05 - val_loss: 7.9824e-04
# Epoch 18/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 9.3876e-05 - val_loss: 4.9829e-04
# Epoch 19/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 8.4249e-05 - val_loss: 4.3336e-04
# Epoch 20/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 7.8080e-05 - val_loss: 4.6528e-04
# Epoch 21/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 7.2620e-05 - val_loss: 5.3290e-04
# Epoch 22/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 6.4789e-05 - val_loss: 4.4509e-04
# Epoch 23/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 7.4106e-05 - val_loss: 5.4827e-04
# Epoch 24/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 9.3497e-05 - val_loss: 3.7522e-04
# Epoch 25/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.5171e-05 - val_loss: 3.5830e-04
# Epoch 26/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 7.7608e-05 - val_loss: 5.2298e-04
# Epoch 27/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 7.2424e-05 - val_loss: 4.0579e-04
# Epoch 28/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 9.9098e-05 - val_loss: 4.0252e-04
# Epoch 29/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 6.2161e-05 - val_loss: 5.9022e-04
# Epoch 30/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 6.6127e-05 - val_loss: 7.4574e-04
# Epoch 31/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 6.8959e-05 - val_loss: 9.2346e-04
# Epoch 32/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 6.9149e-05 - val_loss: 3.0409e-04
# Epoch 33/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 9.0546e-05 - val_loss: 7.5589e-04
# Epoch 34/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 5.4024e-05 - val_loss: 2.8640e-04
# Epoch 35/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 6.8036e-05 - val_loss: 2.4998e-04
# Epoch 36/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 7.1416e-05 - val_loss: 8.5046e-04
# Epoch 37/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.6483e-05 - val_loss: 6.9620e-04
# Epoch 38/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.3718e-05 - val_loss: 0.0017
# Epoch 39/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 7.8121e-05 - val_loss: 2.3533e-04
# Epoch 40/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 5.4142e-05 - val_loss: 2.4467e-04
# Epoch 41/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.2922e-05 - val_loss: 3.7145e-04
# Epoch 42/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 5.3922e-05 - val_loss: 5.5509e-04
# Epoch 43/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.7638e-05 - val_loss: 2.2818e-04
# Epoch 44/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 6.5870e-05 - val_loss: 2.0045e-04
# Epoch 45/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.7942e-05 - val_loss: 5.5285e-04
# Epoch 46/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 6.3351e-05 - val_loss: 2.1726e-04
# Epoch 47/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.6724e-05 - val_loss: 1.8213e-04
# Epoch 48/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.9482e-05 - val_loss: 2.0769e-04
# Epoch 49/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.7500e-05 - val_loss: 2.1028e-04
# Epoch 50/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 5.7619e-05 - val_loss: 1.9468e-04
# Epoch 51/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.4702e-05 - val_loss: 6.5595e-04
# Epoch 52/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.1404e-05 - val_loss: 2.9456e-04
# Epoch 53/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 4.0993e-05 - val_loss: 9.8494e-04
# Epoch 54/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.9636e-05 - val_loss: 2.4817e-04
# Epoch 55/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 3.9434e-05 - val_loss: 2.9666e-04
# Epoch 56/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 4.6246e-05 - val_loss: 2.6144e-04
# Epoch 57/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 3.4916e-05 - val_loss: 2.5960e-04
# Epoch 58/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 6.1436e-05 - val_loss: 1.6550e-04
# Epoch 59/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.3845e-05 - val_loss: 3.3935e-04
# Epoch 60/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 3.7645e-05 - val_loss: 4.0848e-04
# Epoch 61/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.6362e-05 - val_loss: 1.6613e-04
# Epoch 62/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.3960e-05 - val_loss: 4.2750e-04
# Epoch 63/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 4.3199e-05 - val_loss: 4.7921e-04
# Epoch 64/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 3.5164e-05 - val_loss: 1.7829e-04
# Epoch 65/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.0938e-05 - val_loss: 0.0014
# Epoch 66/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 5.2873e-05 - val_loss: 1.7028e-04
# Epoch 67/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 3.4560e-05 - val_loss: 1.8780e-04
# Epoch 68/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 3.9029e-05 - val_loss: 2.4080e-04
# Epoch 69/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.0941e-05 - val_loss: 3.2019e-04
# Epoch 70/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.2753e-05 - val_loss: 2.0103e-04
# Epoch 71/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 4.8169e-05 - val_loss: 6.8411e-04
# Epoch 72/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 3.5893e-05 - val_loss: 2.0309e-04
# Epoch 73/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.0566e-05 - val_loss: 8.5861e-04
# Epoch 74/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.7265e-05 - val_loss: 2.0540e-04
# Epoch 75/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.8333e-05 - val_loss: 3.5124e-04
# Epoch 76/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 3.0728e-05 - val_loss: 7.5255e-04
# Epoch 77/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.9422e-05 - val_loss: 6.0865e-04
# Epoch 78/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.9719e-05 - val_loss: 0.0010
# Epoch 79/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.2167e-05 - val_loss: 2.0599e-04
# Epoch 80/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.8480e-05 - val_loss: 1.9779e-04
# Epoch 81/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 4.0531e-05 - val_loss: 6.2453e-04
# Epoch 82/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.2070e-05 - val_loss: 2.3568e-04
# Epoch 83/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.9536e-05 - val_loss: 3.7328e-04
# Epoch 84/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.1781e-05 - val_loss: 1.8299e-04
# Epoch 85/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.5786e-05 - val_loss: 1.9418e-04
# Epoch 86/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 2.5683e-05 - val_loss: 2.8115e-04
# Epoch 87/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.3827e-05 - val_loss: 3.6917e-04
# Epoch 88/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 3.4838e-05 - val_loss: 2.7411e-04
# Epoch 89/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 3.2275e-05 - val_loss: 4.7192e-04
# Epoch 90/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 3.6601e-05 - val_loss: 4.2817e-04
# Epoch 91/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.5776e-05 - val_loss: 1.8659e-04
# Epoch 92/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 3.9632e-05 - val_loss: 2.8813e-04
# Epoch 93/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.7998e-05 - val_loss: 1.8193e-04
# Epoch 94/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 3.1432e-05 - val_loss: 2.5830e-04
# Epoch 95/100
#  7/53 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.8332e-05

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('AAPL LSTM Training and validation loss')
plt.legend(loc=0)
plt.figure()
plt.savefig('AAPL LSTM Training and validation loss.png', format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
y_pred = model.predict(X_test)

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict.shape, test_predict.shape

# %%
# Transform back to original form
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
original_ytrain = scaler.inverse_transform(y_train.reshape(-1,1)) 
original_ytest = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
# Evaluation metrices RMSE and MAE
print("Train data RMSE: ", math.sqrt(mean_squared_error(original_ytrain,train_predict)))
print("Train data MSE: ", mean_squared_error(original_ytrain,train_predict))
print("Train data MAE: ", mean_absolute_error(original_ytrain,train_predict))
print("-------------------------------------------------------------------------------------")
print("Test data RMSE: ", math.sqrt(mean_squared_error(original_ytest,test_predict)))
print("Test data MSE: ", mean_squared_error(original_ytest,test_predict))
print("Test data MAE: ", mean_absolute_error(original_ytest,test_predict))

# %%
print("Train data explained variance regression score:", 
      explained_variance_score(original_ytrain, train_predict))
print("Test data explained variance regression score:", 
      explained_variance_score(original_ytest, test_predict))

# %%
pred_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred.flatten()})
pred_df.head()

# %%
plt.figure(figsize=(8,8))
plt.ylabel('Close', fontsize=16)
plt.plot(pred_df)
plt.title('AAPL LSTM TActual Value'- 'Predictions')
plt.legend(['Actual Value', 'Predictions'])
plt.savefig('LSTM Actual Value' - 'Predictions.png', format='png', dpi=300, bbox_inches='tight')
plt.show()

# %%
AAPL.reset_index(inplace=True)

# %%
# shift train predictions for plotting

look_back=time_step
trainPredictPlot = np.empty_like(closedf)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
print("Train predicted data: ", trainPredictPlot.shape)

# shift test predictions for plotting
testPredictPlot = np.empty_like(closedf)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(closedf)-1, :] = test_predict
print("Test predicted data: ", testPredictPlot.shape)

names = cycle(['Original close price','Train predicted close price','Test predicted close price'])


plotdf = pd.DataFrame({'date': AAPL['Date'],
                       'original_close': AAPL['Close'],
                      'train_predicted_close': trainPredictPlot.reshape(1,-1)[0].tolist(),
                      'test_predicted_close': testPredictPlot.reshape(1,-1)[0].tolist()})

fig = px.line(plotdf,x=plotdf['date'], y=[plotdf['original_close'],plotdf['train_predicted_close'],
                                          plotdf['test_predicted_close']],
              labels={'value':'Stock price','date': 'Date'})
fig.update_layout(title_text='Comparision between original close price vs predicted close price',
                  plot_bgcolor='white', font_size=15, font_color='black', legend_title_text='Close Price')
fig.for_each_trace(lambda t:  t.update(name = next(names)))

fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()

# %%
x_input=test_data[len(test_data)-time_step:].reshape(1,-1)
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

lst_output=[]
n_steps=time_step
i=0
pred_days = 30
while(i<pred_days):
    
    if(len(temp_input)>time_step):
        
        x_input=np.array(temp_input[1:])
        #print("{} day input {}".format(i,x_input))
        x_input = x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        
        yhat = model.predict(x_input, verbose=0)
        #print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
       
        lst_output.extend(yhat.tolist())
        i=i+1
        
    else:
        
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        
        lst_output.extend(yhat.tolist())
        i=i+1
               
print("Output of predicted next days: ", len(lst_output))

# %%
last_days=np.arange(1,time_step+1)
day_pred=np.arange(time_step+1,time_step+pred_days+1)
print(last_days)
print(day_pred)

# %%
temp_mat = np.empty((len(last_days)+pred_days+1,1))
temp_mat[:] = np.nan
temp_mat = temp_mat.reshape(1,-1).tolist()[0]

last_original_days_value = temp_mat
next_predicted_days_value = temp_mat

last_original_days_value[0:time_step+1] = scaler.inverse_transform(closedf[len(closedf)-time_step:]).reshape(1,-1).tolist()[0]
next_predicted_days_value[time_step+1:] = scaler.inverse_transform(np.array(lst_output).reshape(-1,1)).reshape(1,-1).tolist()[0]

new_pred_plot = pd.DataFrame({
    'last_original_days_value':last_original_days_value,
    'next_predicted_days_value':next_predicted_days_value
})

names = cycle(['Last 15 days close price','Predicted next 30 days close price'])

fig = px.line(new_pred_plot,x=new_pred_plot.index, y=[new_pred_plot['last_original_days_value'],
                                                      new_pred_plot['next_predicted_days_value']],
              labels={'value': 'Stock price','index': 'Timestamp'})
fig.update_layout(title_text='Compare last 15 days vs next 30 days',
                  plot_bgcolor='white', font_size=15, font_color='black',legend_title_text='Close Price')

fig.for_each_trace(lambda t:  t.update(name = next(names)))
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()

# %%
lstmdf=closedf.tolist()
lstmdf.extend((np.array(lst_output).reshape(-1,1)).tolist())
lstmdf=scaler.inverse_transform(lstmdf).reshape(1,-1).tolist()[0]

names = cycle(['Close price'])

fig = px.line(lstmdf,labels={'value': 'Stock price','index': 'Timestamp'})
fig.update_layout(title_text='Plotting whole closing stock price with prediction',
                  plot_bgcolor='white', font_size=15, font_color='black',legend_title_text='Stock')

fig.for_each_trace(lambda t:  t.update(name = next(names)))

fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
