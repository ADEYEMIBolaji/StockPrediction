# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

# %%
AAPL = pd.read_csv(r"C:\Users\bolaj\Desktop\Stock Price Prediction\Stock Market Price  Prediction\Methodology\AAPL_daily_data.csv")
TSLA = pd.read_csv('C:/Users/bolaj/Desktop/Stock Price Prediction/Stock Market Price  Prediction/Methodology/TSLA_daily_data.csv')
GOOG = pd.read_csv('C:/Users/bolaj/Desktop/Stock Price Prediction/Stock Market Price  Prediction/Methodology/GOOGL_daily_data.csv')
MSFT = pd.read_csv('C:/Users/bolaj/Desktop/Stock Price Prediction/Stock Market Price  Prediction/Methodology/MSFT_daily_data.csv')
AMZN = pd.read_csv('C:/Users/bolaj/Desktop/Stock Price Prediction/Stock Market Price  Prediction/Methodology/AMZN_daily_data.csv')

# %%
def Test_Stationarity(timeseries):
  result = adfuller(timeseries['Adj Close'], autolag = 'AIC')
  print("Results of Dickey Fuller Test")
  print(f'Test Statistics: {result[0]}')
  print(f'p-value: {result[1]}')
  print(f'Number of lags used: {result[2]}')
  print(f'Number of observations used: {result[3]}')
  for key, value in result[4].items():
    print(f'critical value ({key}): {value}')

# %% [markdown]
# ## APPLE

# %%
AAPL.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2014-01-02  19.845715  19.893929  19.715000  19.754642  17.253258
# 1  2014-01-03  19.745001  19.775000  19.301071  19.320715  16.874277
# 2  2014-01-06  19.194643  19.528570  19.057142  19.426071  16.966291
# 3  2014-01-07  19.440001  19.498571  19.211430  19.287144  16.844963
# 4  2014-01-08  19.243214  19.484285  19.238930  19.409286  16.951632
#
#       Volume
# 0  234684800
# 1  392467600
# 2  412610800
# 3  317209200
# 4  258529600

# %%
AAPL.shape
# Out:
# (2577, 8)

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2577 entries, 0 to 2576
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2577 non-null   object
#  1   Open       2577 non-null   float64
#  2   High       2577 non-null   float64
#  3   Low        2577 non-null   float64
#  4   Close      2577 non-null   float64
#  5   Adj Close  2577 non-null   float64
#  6   Volume     2577 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 141.1+ KB

# %%
AAPL.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'log Adj Close'],
#       dtype='object')

# %%
# Change Dtype of Date column
AAPL["Date"] = pd.to_datetime(AAPL["Date"])

# %%
max_date = AAPL["Date"].max()
max_date
# Out:
# Timestamp('2024-03-28 00:00:00')

# %%
min_date = AAPL["Date"].min()
min_date
# Out:
# Timestamp('2014-01-02 00:00:00')

# %%
AAPL.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2014-01-02  19.845715  19.893929  19.715000  19.754642  17.253258  234684800
# 1 2014-01-03  19.745001  19.775000  19.301071  19.320715  16.874277  392467600
# 2 2014-01-06  19.194643  19.528570  19.057142  19.426071  16.966291  412610800
# 3 2014-01-07  19.440001  19.498571  19.211430  19.287144  16.844963  317209200
# 4 2014-01-08  19.243214  19.484285  19.238930  19.409286  16.951632  258529600

# %%
Test_Stationarity(AAPL)
# Out:
# Results of Dickey Fuller Test
# Test Statistics: -0.24928801206986156
# p-value: 0.9323859039420437
# Number of lags used: 18
# Number of observations used: 2558
# critical value (1%): -3.4329089813516065
# critical value (5%): -2.8626705556366505
# critical value (10%): -2.56737183663938

# %%
AAPL['log Adj Close'] = np.log(AAPL['Adj Close'])
AAPL_log_moving_avg = AAPL['log Adj Close'].rolling(12).mean()
AAPL_log_std = AAPL['log Adj Close'].rolling(12).std()

plt.figure(figsize = (10, 5))
plt.plot(AAPL['Date'], AAPL_log_moving_avg, label = "Rolling Mean")
plt.plot(AAPL['Date'], AAPL_log_std, label = "Rolling Std")
plt.xlabel('Time')
plt.ylabel('log Adj Close')
plt.legend(loc = 'best')
plt.title("Rolling Mean and Standard Deviation")
# Out:
# Text(0.5, 1.0, 'Rolling Mean and Standard Deviation')

# %% [markdown]
# ### Split the data into training and test set
# Training Period: 2014-01-01 - 2023-09-30
#
# Testing Period:  2023-10-01 - 2024-04-01

# %%
AAPL_Train_Data = AAPL[AAPL['Date'] < '2023-10-01']
AAPL_Test_Data = AAPL[AAPL['Date'] >= '2023-10-01'].reset_index(drop = True)

plt.figure(figsize = (10, 5))
plt.plot(AAPL_Train_Data['Date'], AAPL_Train_Data['log Adj Close'], label = 'Train Data')
plt.plot(AAPL_Test_Data['Date'], AAPL_Test_Data['log Adj Close'], label = 'Test Data')
plt.xlabel('Time')
plt.ylabel('log Adj Close')
plt.legend(loc = 'best')

# %%
AAPL_Auto_ARIMA_Model = auto_arima(AAPL_Train_Data['log Adj Close'], seasonal = False,
                                   error_action = 'ignore', suppress_warnings = True)
print(AAPL_Auto_ARIMA_Model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2453
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                6371.561
# Date:                Sat, 24 Aug 2024   AIC                         -12737.122
# Time:                        11:30:41   BIC                         -12719.708
# Sample:                             0   HQIC                        -12730.793
#                                - 2453
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0009      0.000      2.702      0.007       0.000       0.002
# ma.L1         -0.0692      0.013     -5.271      0.000      -0.095      -0.043
# sigma2         0.0003   5.19e-06     62.371      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              2797.32
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.69   Skew:                            -0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
AAPL_ARIMA_Model = ARIMA(AAPL_Train_Data['log Adj Close'], order=(1, 1, 0))
AAPL_ARIMA_Model_Fit = AAPL_ARIMA_Model.fit()
print(AAPL_ARIMA_Model_Fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:          log Adj Close   No. Observations:                 2453
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                6367.761
# Date:                Sat, 24 Aug 2024   AIC                         -12731.522
# Time:                        11:30:57   BIC                         -12719.913
# Sample:                             0   HQIC                        -12727.303
#                                - 2453
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0661      0.013     -5.200      0.000      -0.091      -0.041
# sigma2         0.0003   5.21e-06     62.398      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):              2808.07
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.69   Skew:                            -0.26
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Predicting Closing Stock of Apple

# %%
# Forecast
forecast_steps = len(AAPL_Test_Data)
AAPL_output = AAPL_ARIMA_Model_Fit.forecast(steps=forecast_steps, alpha=0.05)
AAPL_predictions = np.exp(AAPL_output)  

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(AAPL_Train_Data['Date'], AAPL_Train_Data['Adj Close'], label='Training')
plt.plot(AAPL_Test_Data['Date'], AAPL_Test_Data['Adj Close'], label='Testing')
plt.plot(AAPL_Test_Data['Date'], AAPL_predictions, label='Predictions')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %%
# Calculate RMSE and MAPE
rmse = math.sqrt(mean_squared_error(AAPL_Test_Data['Adj Close'], AAPL_predictions))

# Handle division by zero in MAPE calculation
AAPL_Test_Data['Adj Close'] = AAPL_Test_Data['Adj Close'].replace(0, np.nan)
mape = np.mean(np.abs(AAPL_predictions - AAPL_Test_Data['Adj Close']) / np.abs(AAPL_Test_Data['Adj Close']))

# %%
print(f'RMSE: {rmse}')
print(f'MAPE: {mape}')
# Out:
# RMSE: 14.816685950435568
# MAPE: nan

# %% [markdown]
# ## TESLA

# %%
TSLA.head()
# Out:
#          Date       Open       High       Low      Close  Adj Close    Volume
# 0  2014-01-02   9.986667  10.165333  9.770000  10.006667  10.006667  92826000
# 1  2014-01-03  10.000000  10.146000  9.906667   9.970667   9.970667  70425000
# 2  2014-01-06  10.000000  10.026667  9.682667   9.800000   9.800000  80416500
# 3  2014-01-07   9.841333  10.026667  9.683333   9.957333   9.957333  75511500
# 4  2014-01-08   9.923333  10.246667  9.917333  10.085333  10.085333  92448000

# %%
# Change Dtype of Date column
TSLA["Date"] = pd.to_datetime(TSLA["Date"])

# %%
Test_Stationarity(TSLA)
# Out:
# Results of Dickey Fuller Test
# Test Statistics: -1.2671667948942626
# p-value: 0.6440565326130601
# Number of lags used: 28
# Number of observations used: 2548
# critical value (1%): -3.432919034594598
# critical value (5%): -2.862674995236558
# critical value (10%): -2.5673742003270332

# %%
TSLA.shape
# Out:
# (2577, 7)

# %%
TSLA['log Adj Close'] = np.log(TSLA['Adj Close'])
TSLA_log_moving_avg = TSLA['log Adj Close'].rolling(12).mean()
TSLA_log_std = TSLA['log Adj Close'].rolling(12).std()

plt.figure(figsize = (10, 5))
plt.plot(TSLA['Date'], TSLA_log_moving_avg, label = "Rolling Mean")
plt.plot(AAPL['Date'], TSLA_log_std, label = "Rolling Std")
plt.xlabel('Time')
plt.ylabel('log Adj Close')
plt.legend(loc = 'best')
plt.title("Rolling Mean and Standard Deviation")
# Out:
# Text(0.5, 1.0, 'Rolling Mean and Standard Deviation')

# %%
TSLA_Train_Data = TSLA[TSLA['Date'] < '2023-10-01']
TSLA_Test_Data = TSLA[TSLA['Date'] >= '2023-10-01'].reset_index(drop = True)

plt.figure(figsize = (10, 5))
plt.plot(TSLA_Train_Data['Date'], TSLA_Train_Data['log Adj Close'], label = 'Train Data')
plt.plot(TSLA_Test_Data['Date'], TSLA_Test_Data['log Adj Close'], label = 'Test Data')
plt.xlabel('Time')
plt.ylabel('log Adj Close')
plt.legend(loc = 'best')

# %%
TSLA_Auto_ARIMA_Model = auto_arima(TSLA_Train_Data['log Adj Close'], seasonal = False,
                                   error_action = 'ignore', suppress_warnings = True)
print(TSLA_Auto_ARIMA_Model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1195
# Model:               SARIMAX(2, 1, 2)   Log Likelihood                2115.760
# Date:                Tue, 30 Jul 2024   AIC                          -4221.520
# Time:                        12:38:37   BIC                          -4196.095
# Sample:                             0   HQIC                         -4211.940
#                                - 1195
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7524      0.057     13.136      0.000       0.640       0.865
# ar.L2         -0.8588      0.051    -16.719      0.000      -0.959      -0.758
# ma.L1         -0.7674      0.046    -16.764      0.000      -0.857      -0.678
# ma.L2          0.9121      0.042     21.728      0.000       0.830       0.994
# sigma2         0.0017   4.37e-05     38.593      0.000       0.002       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               567.90
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.76   Skew:                            -0.24
# Prob(H) (two-sided):                  0.01   Kurtosis:                         6.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
TSLA_ARIMA_Model = ARIMA(TSLA_Train_Data['log Adj Close'], order=(1, 1, 0))
TSLA_ARIMA_Model_Fit = TSLA_ARIMA_Model.fit()
print(TSLA_ARIMA_Model_Fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:          log Adj Close   No. Observations:                 1195
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                2109.395
# Date:                Tue, 30 Jul 2024   AIC                          -4214.790
# Time:                        12:39:03   BIC                          -4204.620
# Sample:                             0   HQIC                         -4210.958
#                                - 1195
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0065      0.023     -0.287      0.774      -0.051       0.038
# sigma2         0.0017   4.24e-05     40.326      0.000       0.002       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               639.28
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.76   Skew:                            -0.26
# Prob(H) (two-sided):                  0.01   Kurtosis:                         6.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Predicting Closing Stock of TESLA

# %%
# Forecast
forecast_steps = len(TSLA_Test_Data)
TSLA_output = TSLA_ARIMA_Model_Fit.forecast(steps=forecast_steps, alpha=0.05)
TSLA_predictions = np.exp(TSLA_output)  

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(TSLA_Train_Data['Date'], TSLA_Train_Data['Adj Close'], label='Training')
plt.plot(TSLA_Test_Data['Date'], TSLA_Test_Data['Adj Close'], label='Testing')
plt.plot(TSLA_Test_Data['Date'], TSLA_predictions, label='Predictions')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %%
# Calculate RMSE and MAPE
rmse = math.sqrt(mean_squared_error(TSLA_Test_Data['Adj Close'], TSLA_predictions))

# Handle division by zero in MAPE calculation
TSLA_Test_Data['Adj Close'] = TSLA_Test_Data['Adj Close'].replace(0, np.nan)
mape = np.mean(np.abs(TSLA_predictions - TSLA_Test_Data['Adj Close']) / np.abs(TSLA_Test_Data['Adj Close']))

# %%
print(f'RMSE: {rmse}')
print(f'MAPE: {mape}')
# Out:
# RMSE: 43.99408892623491
# MAPE: nan

# %% [markdown]
# ## GOOGLE

# %%
GOOG.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2014-01-02  27.914413  27.971722  27.734234  27.855856  27.823923
# 1  2014-01-03  27.902903  27.951200  27.650902  27.652653  27.620953
# 2  2014-01-06  27.853104  27.999498  27.688688  27.960960  27.928907
# 3  2014-01-07  28.153152  28.520771  28.057056  28.500000  28.467329
# 4  2014-01-08  28.678679  28.711712  28.360611  28.559309  28.526569
#
#       Volume
# 0   72783144
# 1   66601332
# 2   70701228
# 3  102001896
# 4   89610300

# %%
GOOG.shape
# Out:
# (2577, 7)

# %%
MSFT.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2014-01-02  37.349998  37.400002  37.099998  37.160000  31.120733  30632200
# 1  2014-01-03  37.200001  37.220001  36.599998  36.910000  30.911366  31134800
# 2  2014-01-06  36.849998  36.889999  36.110001  36.130001  30.258125  43603700
# 3  2014-01-07  36.330002  36.490002  36.209999  36.410000  30.492617  35802800
# 4  2014-01-08  36.000000  36.139999  35.580002  35.759998  29.948267  59971700

# %%
AMZN.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2020-01-02  93.750000  94.900497  93.207497  94.900497  94.900497  80580000
# 1  2020-01-03  93.224998  94.309998  93.224998  93.748497  93.748497  75288000
# 2  2020-01-06  93.000000  95.184502  93.000000  95.143997  95.143997  81236000
# 3  2020-01-07  95.224998  95.694504  94.601997  95.343002  95.343002  80898000
# 4  2020-01-08  94.902000  95.550003  94.321999  94.598503  94.598503  70160000
